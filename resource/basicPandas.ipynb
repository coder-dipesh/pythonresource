# %% [markdown]
# ![image.png](attachment:194f0f79-658f-458a-9aca-b2f77b358b3c.png)

# %% [markdown]
# Pandas is a Python library.
#
# Pandas is used to analyze data.

# %% [markdown]
# Pandas is an open-source library that is built on top of NumPy library.
#
# It is a Python package that offers various data structures and operations for **manipulating numerical data and time series**.
#
# It is mainly popular for importing and analyzing data much easier.

# %%
import pandas as pd

# %%
cardata = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

cardataf = pd.DataFrame(cardata)

print(cardataf)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# # DATA STRUCTURE IN PANDAS

# %% [markdown]
# A data structure is a way to arrange the data in such a way that so it
# can be accessed quickly and we can perform various operation on this
# data like- retrieval, deletion, modification etc.

# %% [markdown]
# Pandas deals with 3 data structure
# - Series
# - Data Frame
# - Panel

# %% [markdown]
# We are having only series and data frame in our syllabus.

# %% [markdown]
# # Series

# %% [markdown]
# Series is a one-dimensional array like structure with
# homogeneous data, which can be used to handle and manipulate data.
# What makes it special is its index attribute, which has incredible
# functionality and is heavily mutable.

# %% [markdown]
# It has two parts
# - Data part (An array of actual data)
# - Associated index with data (associated array of indexes or data labels)

# %% [markdown]
# ✓ We can say that Series is a labeled one-dimensional array
# which can hold any type of data.
#
# ✓ Data of Series is always mutable, means it can be changed.
#
# ✓ But the size of Data of Series is always immutable, means it
# cannot be changed.
#
# ✓ Series may be considered as a Data Structure with two
# arrays out which one array works as Index (Labels) and the
# second array works as original Data.
#
# ✓ Row Labels in Series are called Index.

# %% [markdown]
# Syntax to create a Series

# %% [markdown]
# `<Series Object>=pandas.Series (data, index=idx (optional))`

# %% [markdown]
# #### How to create Series with nd array

# %%
import pandas as pd
import numpy as np 

arr=np.array([10,15,18,22])
s = pd.Series(arr)

print(s)
# Out:
# 0    10
# 1    15
# 2    18
# 3    22
# dtype: int64

# %% [markdown]
# #### How to create Series with Mutable index

# %%
import pandas as pd
import numpy as np

arr=np.array(['a','b','c','d'])
s=pd.Series(arr, index=['first','second','third','fourth'])

print(s)
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object

# %% [markdown]
# #### Creating a series from a Dictionary

# %%
data  = {'Name':'Dipak',
         'Class':'9',
         'Grade':'B+',
         'Gender': "M",
        }

s = pd.Series(data)
print(type(data))

print(s)
print(s.iloc[2])
# Out:
# <class 'dict'>
# Name      Dipak
# Class         9
# Grade        B+
# Gender        M
# dtype: object
# B+

# %% [markdown]
# #### Selection in Series

# %%
arr = np.array([10,11,12,13,14,15])
s = pd.Series(arr)

#printing original series
print(s)
# to print values from index 0 to 2
print(s.loc[:2])
# to print values from index 3 to 4
print(s.loc[3:4])
# Out:
# 0    10
# 1    11
# 2    12
# 3    13
# 4    14
# 5    15
# dtype: int64
# 0    10
# 1    11
# 2    12
# dtype: int64
# 3    13
# 4    14
# dtype: int64

# %% [markdown]
# #### Indexing in series

# %%
arr=np.array(['a','b','c','d'])
s=pd.Series(arr,
index=['first','second','third','fourth'])

print(s)
print(s.index)
# Out:
# first     a
# second    b
# third     c
# fourth    d
# dtype: object
# Index(['first', 'second', 'third', 'fourth'], dtype='object')

# %% [markdown]
# # Pandas DataFrame

# %% [markdown]
# Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
#
# - data
# - rows
# - columns

# %% [markdown]
# #### Properties of Dataframe

# %% [markdown]
# - A Dataframe has axes (indices)-
# > Row index (axis=0)
# >
# > Column index (axis=1)
# - It is similar to a spreadsheet , whose row index is called index and
# column index is called column name.
# - A Dataframe contains Heterogeneous data.
# - A Dataframe Size is Mutable.
# - A Dataframe Data is Mutable.

# %% [markdown]
# ![Image](https://media.geeksforgeeks.org/wp-content/uploads/finallpandas.png)

# %% [markdown]
# ### Creating a Pandas DataFrame

# %% [markdown]
# Pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, and Excel file.

# %% [markdown]
# Pandas DataFrame can be created from the lists, dictionary, and from a list of dictionary etc.

# %% [markdown]
# #### Creating a dataframe using List:

# %%
# list of strings
listData = ['Python', 'for', 'Data', 'Science', 
            'and', 'WebDevelopers', ]
 
# Calling DataFrame constructor on list
df = pd.DataFrame(listData)
print(df)
# Out:
#                0
# 0         Python
# 1            for
# 2           Data
# 3        Science
# 4            and
# 5  WebDevelopers

# %% [markdown]
# #### Creating DataFrame from dict of ndarray/lists:

# %% [markdown]
# To create DataFrame from dict of `narray/list`, all the narray must be of same length.

# %%
# intialise data of lists.
data = {'Name':['Tom', 'William', 'John', 'Jack'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#       Name  Age
# 0      Tom   20
# 1  William   21
# 2     John   19
# 3     Jack   18

# %% [markdown]
# #### Create pandas dataframe from lists using dictionary:

# %%
# dictionary of lists
data = {'name':["sushan", "aryan", "sudhir", "pratik"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
df = pd.DataFrame(data)
 
print(df)
# Out:
#      name  degree  score
# 0  sushan     MBA     90
# 1   aryan     BCA     40
# 2  sudhir  M.Tech     80
# 3  pratik     MBA     98

# %% [markdown]
# ### Understanding Rows and Columns

# %% [markdown]
# #### Column Selection

# %% [markdown]
# To select a column in Pandas DataFrame, we can either access the columns by calling them by their columns name.

# %%
data = {'Name':['Dev', 'Khem', 'Nishal', 'Saurab'],
        'Age':[27, 24, 22, 32],
        'Address':['Ktm', 'Pkr', 'Brt', 'Btm'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
 

df = pd.DataFrame(data)
 
# select two columns
print(df[['Name','Age']])
# Out:
#      Name  Age
# 0     Dev   27
# 1    Khem   24
# 2  Nishal   22
# 3  Saurab   32

# %% [markdown]
# #### Row Selection

# %% [markdown]
# - `DataFrame.loc[]` method is used to retrieve rows from Pandas DataFrame.
# - Rows can also be selected by passing integer location to an `iloc[]` function.

# %%
# making data frame from csv file 
data = pd.read_csv("datasets/nba.csv")

data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# making data frame from csv file 
data = pd.read_csv("datasets/nba.csv", index_col="Name")

data

# retrieving row by loc method
first = data.loc["Avery Bradley"]
second = data.loc["R.J. Hunter"]
 
first
# print(first, "\n\n\n", second)
# Out:
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: Avery Bradley, dtype: object

# %%
# making data frame from csv file 
data = pd.read_csv("datasets/nba.csv", index_col ="Name") 

# retrieving rows by loc method 
rows = data.loc[["Avery Bradley", "R.J. Hunter"]] 
  
# checking data type of rows 
print(type(rows)) 
  
# display 
rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                          Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# R.J. Hunter    Boston Celtics    28.0       SG  22.0    6-5   185.0
#
#                      College     Salary
# Name
# Avery Bradley          Texas  7730337.0
# R.J. Hunter    Georgia State  1148640.0

# %% [markdown]
# #### Extracting multiple rows with same index

# %%
# making data frame from csv file 
data = pd.read_csv("datasets/nba.csv", index_col ="Team") 
  
# retrieving rows by loc method 
rows = data.loc["Utah Jazz"] 
  
# checking data type of rows 
print(type(rows)) 
  
# display 
rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                      Name  Number Position   Age Height  Weight       College  \
# Team
# Utah Jazz   Trevor Booker    33.0       PF  28.0    6-8   228.0       Clemson
# Utah Jazz      Trey Burke     3.0       PG  23.0    6-1   191.0      Michigan
# Utah Jazz      Alec Burks    10.0       SG  24.0    6-6   214.0      Colorado
# Utah Jazz      Dante Exum    11.0       PG  20.0    6-6   190.0           NaN
# Utah Jazz  Derrick Favors    15.0       PF  24.0   6-10   265.0  Georgia Tech
# Utah Jazz     Rudy Gobert    27.0        C  23.0    7-1   245.0           NaN
# Utah Jazz  Gordon Hayward    20.0       SF  26.0    6-8   226.0        Butler
# Utah Jazz     Rodney Hood     5.0       SG  23.0    6-8   206.0          Duke
# Utah Jazz      Joe Ingles     2.0       SF  28.0    6-8   226.0           NaN
# Utah Jazz   Chris Johnson    23.0       SF  26.0    6-6   206.0        Dayton
# ...

# %% [markdown]
# #### Using `iloc[]`

# %% [markdown]
# `.iloc[]` is an indexer used for integer-location-based indexing of data in a DataFrame.

# %% [markdown]
# - `Dataframe.iloc[]` method is used when the index label of a data frame is something other than numeric series of 0, 1, 2, 3….n
#  or in case the user doesn’t know the index label.
# - Rows can be extracted using an imaginary index position that isn’t visible in the Dataframe.

# %% [markdown]
# `.iloc[]` in Python is a powerful tool for extracting rows based on integer-location indexing.

# %%
# making data frame from csv file 
data = pd.read_csv("datasets/nba.csv") 


# retrieving rows by iloc method
row2 = data.iloc[3]


row2
# Out:
# Name           R.J. Hunter
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: 3, dtype: object

# %% [markdown]
# #### Selecting Multiple Rows using Pandas .iloc[] in Python

# %%
# making data frame from csv file
data = pd.read_csv('datasets/nba.csv')
 
# retrieving rows by loc method
row1 = data.iloc[[4, 5, 6, 7]]
 
# retrieving rows by loc method
row2 = data.iloc[4:8]
 
# comparing values
row1 == row2
# Out:
#    Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 4  True  True    True      True  True    True    True    False    True
# 5  True  True    True      True  True    True    True    False    True
# 6  True  True    True      True  True    True    True     True    True
# 7  True  True    True      True  True    True    True     True    True

# %% [markdown]
# ### Select Operation in data frame

# %% [markdown]
# To access the column data ,we can mention the column name as
# subscript.

# %%
# dictionary of lists
data = {'name':["sushan", "aryan", "sudhir", "pratik"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
df = pd.DataFrame(data)
 
print(df.name)
print(df['degree'])
# Out:
# 0    sushan
# 1     aryan
# 2    sudhir
# 3    pratik
# Name: name, dtype: object
# 0       MBA
# 1       BCA
# 2    M.Tech
# 3       MBA
# Name: degree, dtype: object

# %% [markdown]
# ### Add & Rename a column in data frame

# %%
s = pd.Series([10,15,18,22])

df = pd.DataFrame(s)

# To Rename the default column of DataFrame as List1
df.columns = ['List1']

# To create a new column List2 with all values as 20 
df['List2'] = 20

# Add Column1 and Column2 and store in New column List3
df['List3'] = df['List1'] + df['List2']

print(df)
# Out:
#    List1  List2  List3
# 0     10     20     30
# 1     15     20     35
# 2     18     20     38
# 3     22     20     42

# %%
nbadata = pd.read_csv('datasets/nba.csv')

df = pd.DataFrame(nbadata)

df.rename(columns = {'Name':'Full Name'}, inplace = True)

df
# Out:
#          Full Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Delete a Column Using `drop()`

# %%
# creating a series
s = pd.Series([10,20,30,40])

# converting to dataframe
df = pd.DataFrame(s)

# renaming column
df.columns = ['List1']

df['List2'] = 40

# (axis=1) means to delete Data column wise
df1 = df.drop('List2',axis=1) 

# (axis=0) means to delete data row wise with given index
df2 = df.drop(index=[2,3], axis = 0)

print(df)

print('After col deletion::')
print(df1)

print ('After row deletion::')
print(df2)
# Out:
#    List1  List2
# 0     10     40
# 1     20     40
# 2     30     40
# 3     40     40
# After deletion::
#    List1
# 0     10
# 1     20
# 2     30
# 3     40
# After row deletion::
#    List1  List2
# 0     10     40
# 1     20     40

# %% [markdown]
# #### Alignment

# %%
# align content to left 
nbadata = pd.read_csv('datasets/nba.csv')
df = pd.DataFrame(nbadata)

left_aligned_df = df.style.set_properties(**{'text-align': 'left'})

display(left_aligned_df)
# Out:
# <style type="text/css">
# ...

# %%
# align left to both column name and data 

left_aligned_df = df.style.set_properties(**{'text-align': 'left'})
 
left_aligned_df = left_aligned_df.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
 
display(left_aligned_df)
# Out:
# <style type="text/css">
# #T_ea80a th {
#   text-align: left;
# }
# ...

# %% [markdown]
# #### Rank and Sort

# %%
# creating movie data
movies = {'Name': ['The Godfather', 'Bird Box', 'Fight Club'], 
         'Year': ['1972', '2018', '1999'], 
         'Rating': ['9.2', '6.8', '8.8']} 

# creatign dataframe
df = pd.DataFrame(movies) 

print(df)
# Out:
#             Name  Year Rating
# 0  The Godfather  1972    9.2
# 1       Bird Box  2018    6.8
# 2     Fight Club  1999    8.8

# %%
# Create a column ratingRank which contains 
# the rank of each movie based on rating 
df['ratingRank'] = df['Rating'].rank(ascending = 1) 
  
# Set the index to newly created column, ratingRank 
df = df.set_index('ratingRank') 
print(df)
# Out:
#                      Name  Year Rating
# ratingRank
# 3.0         The Godfather  1972    9.2
# 1.0              Bird Box  2018    6.8
# 2.0            Fight Club  1999    8.8

# %% [markdown]
# # Analyzing DataFrames

# %% [markdown]
# One of the most used method for getting a quick overview of the DataFrame, is the head() method.
#
# The head() method returns the headers and a specified number of rows, starting from the top.

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# There is also a tail() method for viewing the last rows of the DataFrame.
#
# The tail() method returns the headers and a specified number of rows, starting from the bottom.

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# ### Info About the Data

# %% [markdown]
# The DataFrames object has a method called info(), that gives you more information about the data set.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB
# None

# %% [markdown]
# ### Null Values

# %% [markdown]
# The `info()` method also tells us how many Non-Null values there are present in each column

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# #### Cleaning Empty Cells

# %% [markdown]
# Empty cells can potentially give you a wrong result when you analyze data.

# %% [markdown]
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %% [markdown]
# Return a new Data Frame with no empty cells:
# Note: By default, the dropna() method returns a new DataFrame, and will not change the original.

# %%
df = pd.read_csv('datasets/nba.csv')

print(df)

new_df = df.dropna()


print(new_df.to_string())
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# If you want to change the original DataFrame, use the `inplace = True` argument:
#
# Remove all rows with NULL values:

# %%
df = pd.read_csv('datasets/nba.csv')

df.dropna(inplace = True)

print(df.to_string())

# %% [markdown]
# **Note:** Now, the `dropna(inplace = True)` will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %% [markdown]
# #### Replace Empty Values

# %% [markdown]
# - Another way of dealing with empty cells is to insert a new value instead.
#
# - This way you do not have to delete entire rows just because of some empty cells.
#
# - The `fillna()` method allows us to replace empty cells with a value:

# %% [markdown]
# Replace NULL values with the number 130:

# %%
df = pd.read_csv('datasets/nba.csv')

df.fillna(130, inplace = True)

# %% [markdown]
# #### Replace Only For Specified Columns

# %% [markdown]
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
df = pd.read_csv('datasets/nba.csv')

df["Column Name"].fillna(130, inplace = True)

# %%
import numpy as np

# %%
stu = {'name':["sushan", "aryan", "sudhir", "pratik"],
        'degree': ["MBA", "BCA", pd.NaT , "MBA"],
        'score':[90, np.nan, 80, 45]}
 
dataF = pd.DataFrame(stu)
dataF
print(type(dataF))
dataF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   degree  3 non-null      object
#  2   score   3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes

# %%
dataF.fillna(70)
# Out:
#      name degree  score
# 0  sushan    MBA   90.0
# 1   aryan    BCA   70.0
# 2  sudhir     70   80.0
# 3  pratik    MBA   45.0

# %%
# dff = dataF.dropna()

# dataF.dropna(inplace=True)

# After droping na 
dff
# Out:
#      name degree  score
# 0  sushan    MBA   90.0
# 3  pratik    MBA   45.0

# %%
dataF["degree"].fillna("CSIT", inplace= True)
dataF
# Out:
# /var/folders/m1/6qb6s__j6mqd9st00bgtgxf40000gn/T/ipykernel_84363/3071383918.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataF["degree"].fillna("CSIT", inplace= True)
#      name degree  score
# 0  sushan    MBA   90.0
# 1   aryan    BCA    NaN
# 2  sudhir   CSIT   80.0
# 3  pratik    MBA   45.0

# %%
stu = {'name':["sushan", "aryan", "sudhir", "pratik"],
        'degree': ["MBA", "BCA", pd.NaT , "MBA"],
        'score':[90, np.nan, 80, 45],
       
      }
 
dataF = pd.DataFrame(stu)
dataF
# Out:
#      name degree  score
# 0  sushan    MBA   90.0
# 1   aryan    BCA    NaN
# 2  sudhir    NaT   80.0
# 3  pratik    MBA   45.0

# %%
x = dataF["score"].mean()

dataF["score"].fillna(x, inplace= True)
dataF
# Out:
# /var/folders/m1/6qb6s__j6mqd9st00bgtgxf40000gn/T/ipykernel_84363/1798014796.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataF["score"].fillna(x, inplace= True)
#      name degree      score
# 0  sushan    MBA  90.000000
# 1   aryan    BCA  71.666667
# 2  sudhir    NaT  80.000000
# 3  pratik    MBA  45.000000

# %% [markdown]
# #### Replace Using Mean, Median, or Mode

# %% [markdown]
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pandas uses the `mean()` `median()` and `mode()` methods to calculate the respective values for a specified column:

# %%
df = pd.read_csv('datasets/nba.csv')

x = df["Col Name"].mean()

df["Col name"].fillna(x, inplace = True)

# %% [markdown]
# **Mean** = the average value (the sum of all values divided by number of values).

# %%
df = pd.read_csv('datasets/nba.csv')

x = df["Col Name"].median()

df["Col Name"].fillna(x, inplace = True)

# %% [markdown]
# **Median** = the value in the middle, after you have sorted all values ascending.

# %%
df = pd.read_csv('datasets/nba.csv')

x = df["Col Name"].mode()[0]

df["Col Name"].fillna(x, inplace = True)

# %% [markdown]
# **Mode** = the value that appears most frequently.

# %%
df = pd.read_csv('datasets/nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 16407500.0     5
#               ..
# 2100000.0      1
# 1252440.0      1
# 2891760.0      1
# 3272091.0      1
# 900000.0       1
# Name: count, Length: 309, dtype: int64

# %%
### Data Wrangling

# %%
#### Data Exploration

# %%
# create data
data = {'Name': ['Rohan', 'Pooja', 'Karma', 
                 'Aayush', 'Rajan', 'Sushila', 'Arya'],
        'Age': [17, 17, 18, 17, 18, 17, 17],
        'Gender': ['M', 'F', 'M', 'M', 'M', 'F', 'F'],
        'Marks': [90, 76, 'NaN', 74, 65, 'NaN', 71]}
 
# Convert into DataFrame
df = pd.DataFrame(data)
 
# Display data
df
# Out:
#       Name  Age Gender Marks
# 0    Rohan   17      M    90
# 1    Pooja   17      F    76
# 2    Karma   18      M   NaN
# 3   Aayush   17      M    74
# 4    Rajan   18      M    65
# 5  Sushila   17      F   NaN
# 6     Arya   17      F    71

# %%
# Compute average
c = avg = 0
for ele in df['Marks']:
    if str(ele).isnumeric():
        c += 1
        avg += ele
avg /= c
 
# Replace missing values
df = df.replace(to_replace="NaN",
                value=avg)
 
# Display data
df
# Out:
# /var/folders/m1/6qb6s__j6mqd9st00bgtgxf40000gn/T/ipykernel_84363/3735188636.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(to_replace="NaN",
#       Name  Age Gender  Marks
# 0    Rohan   17      M   90.0
# 1    Pooja   17      F   76.0
# 2    Karma   18      M   75.2
# 3   Aayush   17      M   74.0
# 4    Rajan   18      M   65.0
# 5  Sushila   17      F   75.2
# 6     Arya   17      F   71.0

# %%
# Categorize gender
df['Gender'] = df['Gender'].map({'M': 0, 
                                 'F': 1, }).astype(float)
 
# Display data
df
# Out:
#       Name  Age  Gender  Marks
# 0    Rohan   17     0.0   90.0
# 1    Pooja   17     1.0   76.0
# 2    Karma   18     0.0   75.2
# 3   Aayush   17     0.0   74.0
# 4    Rajan   18     0.0   65.0
# 5  Sushila   17     1.0   75.2
# 6     Arya   17     1.0   71.0

# %%
#### Filtering data in Data Wrangling

# %%
# Filter top scoring students
df = df[df['Marks'] >= 75].copy()
 
# Remove age column from filtered DataFrame
df.drop('Age', axis=1, inplace=True)
 
# Display data
df
# Out:
#       Name  Gender  Marks
# 0    Rohan     0.0   90.0
# 1    Pooja     1.0   76.0
# 2    Karma     0.0   75.2
# 5  Sushila     1.0   75.2

# %% [markdown]
# #### Data Wrangling  Using Merge Operation

# %%
# Creating Dataframe
details = pd.DataFrame({
    'ID': [101, 102, 103, 104, 105, 
           106, 107, 108, 109, 110],
    'NAME': ['Jagroop', 'Praveen', 'Harjot', 
             'Pooja', 'Rahul', 'Nikita',
             'Saurabh', 'Ayush', 'Dolly', "Mohit"],
    'BRANCH': ['CSE', 'CSE', 'CSE', 'CSE', 'CSE', 
               'CSE', 'CSE', 'CSE', 'CSE', 'CSE']})
 
# Creating Dataframe
fees_status = pd.DataFrame(
    {'ID': [101, 102, 103, 104, 105, 
            106, 107, 108, 109, 110],
     'PENDING': ['5000', '250', 'NIL', 
                 '9000', '15000', 'NIL',
                 '4500', '1800', '250', 'NIL']})
 
# Merging Dataframe
print(pd.merge(details, fees_status, on='ID'))
# Out:
#     ID     NAME BRANCH PENDING
# 0  101  Jagroop    CSE    5000
# 1  102  Praveen    CSE     250
# 2  103   Harjot    CSE     NIL
# 3  104    Pooja    CSE    9000
# 4  105    Rahul    CSE   15000
# 5  106   Nikita    CSE     NIL
# 6  107  Saurabh    CSE    4500
# 7  108    Ayush    CSE    1800
# 8  109    Dolly    CSE     250
# 9  110    Mohit    CSE     NIL

# %% [markdown]
# #### Group Method

# %%
# Creating Data
car_selling_data = {'Brand': ['Ford', 'Nissan', 'Nissan', 
                              'Nissan', 'Hyundai', 'Hyundai', 
                              'Toyota', 'Mahindra', 'Mahindra', 
                              'Ford', 'Toyota', 'Ford'],
                    'Year':  [2010, 2011, 2009, 2013, 
                              2010, 2011, 2011, 2010, 
                              2013, 2010, 2010, 2011],
                    'Sold': [6, 7, 9, 8, 3, 5, 
                             2, 8, 7, 2, 4, 2]}
 
# Creating Dataframe for Provided Data
df = pd.DataFrame(car_selling_data)
 
# Group the data when year = 2010
grouped = df.groupby('Year')
print(grouped.get_group(2010))
# Out:
#        Brand  Year  Sold
# 0       Ford  2010     6
# 4    Hyundai  2010     3
# 7   Mahindra  2010     8
# 9       Ford  2010     2
# 10    Toyota  2010     4

# %% [markdown]
# #### Remove Duplicate

# %%
# creating Data
student_data = {'Name': ['Amit', 'Praveen', 'Jagroop', 
                         'Rahul', 'Vishal', 'Suraj', 
                         'Rishab', 'Satyapal', 'Amit', 
                         'Rahul', 'Praveen', 'Amit'],
 
                'Roll_no': [23, 54, 29, 36, 59, 38, 
                            12, 45, 34, 36, 54, 23],
                
                'Email': ['xxxx@gmail.com', 'xxxxxx@gmail.com', 
                          'xxxxxx@gmail.com', 'xx@gmail.com', 
                          'xxxx@gmail.com', 'xxxxx@gmail.com', 
                          'xxxxx@gmail.com', 'xxxxx@gmail.com', 
                          'xxxxx@gmail.com', 'xxxxxx@gmail.com',
                          'xxxxxxxxxx@gmail.com', 'xxxxxxxxxx@gmail.com']}
 
# creating dataframe
df = pd.DataFrame(student_data)
 
# Here df.duplicated() list duplicate  Entries in ROllno.

# So that ~(NOT) is placed in order to get non duplicate values.
non_duplicate = df[~df.duplicated('Roll_no')]
 
# printing non-duplicate values
print(non_duplicate)
# Out:
#        Name  Roll_no             Email
# 0      Amit       23    xxxx@gmail.com
# 1   Praveen       54  xxxxxx@gmail.com
# 2   Jagroop       29  xxxxxx@gmail.com
# 3     Rahul       36      xx@gmail.com
# 4    Vishal       59    xxxx@gmail.com
# 5     Suraj       38   xxxxx@gmail.com
# 6    Rishab       12   xxxxx@gmail.com
# 7  Satyapal       45   xxxxx@gmail.com
# 8      Amit       34   xxxxx@gmail.com

# %% [markdown]
# ### Data Correlations

# %% [markdown]
# #### Finding Relationships

# %% [markdown]
# A great aspect of the Pandas module is the corr() method.
#
# The `corr()` method calculates the relationship between each column in your data set.

# %%
data = pd.read_csv('datasets/data.csv')
df = pd.DataFrame(data)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# **Note:** The `corr()` method ignores "not numeric" columns.

# %% [markdown]
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %% [markdown]
# **What is a good correlation?** It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.

# %% [markdown]
# Perfect Correlation: `1.000000`

# %% [markdown]
# Good Correlation: `0.922721`

# %% [markdown]
# Bad Correlation: `0.009403`

# %% [markdown]
# ### Ploting with pandas

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# In the example below we will use `"Duration"` for the `x-axis` and `"Calories"` for the `y-axis.`
#
# Include the x and y arguments like this:
#
# `x = 'Duration', y = 'Calories'`

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()

# %% [markdown]
# **Remember:** In the previous example, we learned that the correlation between "Duration" and "Calories" was 0.922721, and we concluded with the fact that higher duration means more calories burned.
#
# By looking at the scatterplot, I will agree.

# %% [markdown]
# Let's create another scatterplot, where there is a bad relationship between the columns, like "Duration" and "Maxpulse", with the correlation `0.009403`
#
# A scatterplot where there are no relationship between the columns:

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Maxpulse')

plt.show()

# %% [markdown]
# ### Histogram

# %% [markdown]
# we pass `kind = 'hist'` to make histogram

# %% [markdown]
# A histogram needs only one column.
#
# A histogram shows us the frequency of each interval, e.g. how many workouts lasted between 50 and 60 minutes?
#
# In the example below we will use the "Duration" column to create the histogram:

# %%
df["Duration"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
